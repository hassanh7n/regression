# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
df = pd.read_csv('./Superstore.csv', encoding='latin1')

# %%
print("Hello, World!")
# Out:
# Hello, World!
